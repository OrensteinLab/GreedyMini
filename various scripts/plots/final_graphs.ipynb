# %%
from scripts.plots import *
# Out:
# module://matplotlib_inline.backend_inline

# %% [markdown]
# # 3D

# %%
#plot_3d_map('matrices/best_dna_density.csv', 'dna_density_factor_after_swap_3d_v2')
#plot_3d_map_interactive_save('matrices/best_dna_density.csv', 'dna_density_factor_after_swap_3d_v2_interactive')

# %% [markdown]
# # Expected Density

# %% [markdown]
# ## Constant w

# %% [markdown]
# ### W = 8

# %%
plot_k_extended(8, "matrices/k_extension_k17_w8.csv", "1_k_extension_k17_w8",17, show_density_factor=False) #TODO: when final extensions use the correct extension positions

# %% [markdown]
# ### W = 12

# %%
plot_k_extended(12, "matrices/k_extension_k16_w12.csv", "2_k_extension_k16_w12",16, show_density_factor=False) #TODO: when final extensions use the correct extension positions

# %% [markdown]
# ## Constant k

# %% [markdown]
# ### k = 8

# %%
plot_w_extended(8, "matrices/w_extension_k8_w19.csv", "3_w_extension_k8_w19",19, 100, show_density_factor=False) #TODO: when final extensions use the correct extension positions

# %% [markdown]
# ### k = 12

# %%
plot_w_extended(12, "matrices/w_extension_k12_w16.csv", "4_w_extension_k12_w16",16, 100, False) #TODO: when final extensions use the correct extension positions

# %%
plot_w_extended_v2(12, "matrices/w_extension_k12_v2.csv", "4_w_extension_k12",16, 100, False) #TODO: when final extensions use the correct extension positions

# %% [markdown]
# ## w = k

# %%
plot_w_is_k("matrices/w_is_k.csv", "7_w_is_k", 50, show_density_factor=False)

# %% [markdown]
# ## w = k - 1

# %%
plot_w_k_is_w_plus_1("matrices/w_is_k_minus_one.csv", "8_w_is_k_minus_one", 50, False)

# %% [markdown]
# ## Density factor heatmap

# %%
plot_heatmap('matrices/best_dna_density.csv', 'dna_density_factor_after_swap_2d')
plot_heatmap('matrices/best_binary_density.csv', 'binary_density_factor_after_swap_2d')

# %% [markdown]
# # Particular Density

# %% [markdown]
# ## 1m X

# %%
plot_k_specific(12, "matrices/1m_run_over_k_w12.csv", "6_1m_run_over_k_w12", False)#TODO: pick colors for GreedyMini and GreedyMini*
plot_w_specific(8, "matrices/1m_run_over_w_k8.csv", "5_1m_run_over_w_k8.csv", False)#TODO: pick colors for GreedyMini and GreedyMini*

# %% [markdown]
# # Mod

# %%
plot_k_extended_mod(8, "matrices/k_extension_k17_w8_with_mod.csv", "001_k_extension_k17_w8_with_mod",17, show_density_factor=False) #TODO: when final extensions use the correct extension positions

# %%
plot_k_extended_mod(12, "matrices/k_extension_k16_w12_with_mod.csv", "002_k_extension_k16_w12",16, show_density_factor=False) #TODO: when final extensions use the correct extension positions
