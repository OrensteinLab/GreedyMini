# %%
from scripts.plots import *

# %%
methods_comparison_path = 'matrices/methods comparison/'

w5_binary_path = methods_comparison_path + 'w5_binary.csv'
w5_dna_path = methods_comparison_path + 'w5_dna.csv'
w8_binary_path = methods_comparison_path + 'w8_binary.csv'
w8_dna_path = methods_comparison_path + 'w8_dna.csv'
w10_binary_path = methods_comparison_path + 'w10_binary.csv'
w10_dna_path = methods_comparison_path + 'w10_dna.csv'
w12_binary_path = methods_comparison_path + 'w12_binary.csv'
w12_dna_path = methods_comparison_path + 'w12_dna.csv'
w16_binary_path = methods_comparison_path + 'w16_binary.csv'
w16_dna_path = methods_comparison_path + 'w16_dna.csv'
w20_binary_path = methods_comparison_path + 'w20_binary.csv'
w20_dna_path = methods_comparison_path + 'w20_dna.csv'
wk_binary_path = methods_comparison_path + 'wk_binary.csv'
wk_dna_path = methods_comparison_path + 'wk_dna.csv'


normal_axis = ['K', 'Density']

plot_fixed_w(5, w5_binary_path, 3, title="w=5, binary", axis_names=normal_axis)
plot_fixed_w(5, w5_dna_path, 3, title="w=5, dna", axis_names=normal_axis)
plot_fixed_w(8, w8_binary_path, 3, title="w=8, binary", axis_names=normal_axis)
plot_fixed_w(8, w8_dna_path, 3, title="w=8, dna", axis_names=normal_axis)
plot_fixed_w(10, w10_binary_path, 3, title="w=10, binary", axis_names=normal_axis)
plot_fixed_w(10, w10_dna_path, 3, title="w=10, dna", axis_names=normal_axis)
plot_fixed_w(12, w12_binary_path, 3, title="w=12, binary", axis_names=normal_axis)
plot_fixed_w(12, w12_dna_path, 3, title="w=12, dna", axis_names=normal_axis)
plot_fixed_w(16, w16_binary_path, 3, title="w=16, binary", axis_names=normal_axis)
plot_fixed_w(16, w16_dna_path, 3, title="w=16, dna", axis_names=normal_axis)
plot_fixed_w(20, w20_binary_path, 3, title="w=20, binary", axis_names=normal_axis)
plot_fixed_w(20, w20_dna_path, 3, title="w=20, dna", axis_names=normal_axis)
plot_fixed_w(0,wk_binary_path, 3, title="w=k, binary", w_equals_k=True, axis_names=['K and W', 'Density'])
plot_fixed_w(0, wk_dna_path, 3, title="w=k, dna", w_equals_k=True, axis_names=['K and W', 'Density'])

# %%
k_extension_path = 'matrices/k extension/'

k12w12_k_extension_path = k_extension_path + 'binary_density_extend_k_k12_w_12.csv'
plot_fixed_w(12, k12w12_k_extension_path, 13, title="k extension of w = 12 k = 12", axis_names=['K', 'Density'])

# %%
w_extension_path = 'matrices/w extension/'
w8k8_dna_w_extension_path = w_extension_path + 'w8k8_dna.csv'
w8k14_binary_w_extension_path = w_extension_path + 'w8k14_binary.csv'

plot_extended_w(8, w8k8_dna_w_extension_path, title="w extension of w = 8 k = 8, DNA", axis_names=['W', 'Density'])
plot_extended_w(14, w8k14_binary_w_extension_path, title="w extension of w = 8 k = 14, binary", axis_names=['W', 'Density'])

# %%
normal_vs_optimized_path = 'matrices/specific vs not/'

w5_specific_vs_not_path = normal_vs_optimized_path + 'w5.csv'
w8_specific_vs_not_path = normal_vs_optimized_path + 'w8.csv'
w12_specific_vs_not_path = normal_vs_optimized_path + 'w12.csv'

plot_fixed_w(5, w5_specific_vs_not_path, 3, title="w=5, specific vs not", axis_names=normal_axis)
plot_fixed_w(8, w8_specific_vs_not_path, 3, title="w=8, specific vs not", axis_names=normal_axis)
plot_fixed_w(12, w12_specific_vs_not_path, 3, title="w=12, specific vs not", axis_names=normal_axis)
